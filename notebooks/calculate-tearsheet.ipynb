# %% [markdown]
# In this notebook we show how to calculate a table with investment metrics (also known as tearsheet) of a given asset or strategy.

# %%
import tradingenv  # dynamically adds .tearsheet method to pandas objects
import yfinance  # pip install yfinance

# %% [markdown]
# # Data Download

# %%
def download_ticker(ticker: str):
    """Download from yahoo finance the adjusted close price of a ticker."""
    ticker = yfinance.Ticker(ticker)
    history = ticker.history(period="12mo")
    return history['Close']

# Download S&P 500 Total Return Index from Yahoo Finance.
aapl = download_ticker("AAPL").to_frame('Apple Inc.')

# Download S&P 500 Total Return Index from Yahoo Finance.
spx = download_ticker("^SP500TR").to_frame('S&P 500 Total Return')

# Download US Treasury 3 Month Bill ETF from Yahoo Finance.
tbill =  download_ticker("TBIL").to_frame('US Treasury 3 Month Bill')

# %% [markdown]
# # Tearsheets

# %%
# Succinct.
aapl.tearsheet()
# Out:
#                                             Apple Inc.
# Context              From                   2022-09-08
#                      To                     2023-09-07
#                      Years                     0.99726
#                      Observations                  251
#                      Risk-free asset          RiskFree
#                      Risk-free CAGR                0.0
# Return               CAGR                     0.156834
#                      CAGR over cash           0.156834
#                      Overall return           0.156373
# Risk                 Volatility               0.291745
#                      Downside volatility      0.188998
#                      Upside volatility        0.210976
#                      Max drawdown            -0.233755
#                      Martin risk              0.092375
#                      VaR 5%                  -0.030274
#                      VaR 2%                  -0.037505
#                      Expected shortfall 5%   -0.039914
#                      Expected shortfall 2%   -0.049016
# Risk-adjusted return Sharpe ratio             0.537574
#                      Sortino ratio            0.829821
#                      Calmar ratio             0.670935
#                      Martin ratio             1.697802
#                      Omega ratio              1.569427

# %%
# Detailed
aapl.tearsheet(risk_free=tbill, benchmark=spx)
# Out:
#                                                           Apple Inc.
# Context              From                                 2022-09-08
#                      To                                   2023-09-07
#                      Years                                   0.99726
#                      Observations                                251
#                      Risk-free asset        US Treasury 3 Month Bill
#                      Risk-free CAGR                         0.045976
# Return               CAGR                                   0.156834
#                      CAGR over cash                         0.110858
#                      Overall return                         0.156373
# Risk                 Volatility                             0.291745
#                      Downside volatility                    0.188998
#                      Upside volatility                      0.210976
#                      Max drawdown                          -0.233755
#                      Martin risk                            0.092375
#                      VaR 5%                                -0.030274
#                      VaR 2%                                -0.037505
#                      Expected shortfall 5%                 -0.039914
#                      Expected shortfall 2%                 -0.049016
# Risk-adjusted return Sharpe ratio                           0.379983
#                      Sortino ratio                          0.586557
#                      Calmar ratio                           0.474249
#                      Martin ratio                           1.200087
#                      Omega ratio                            1.094664
# Outperformance       Benchmark id               S&P 500 Total Return
#                      CAGR over benchmark                    0.026395
#                      Information ratio                      0.150101
#                      CAPM Alpha                             0.018314
#                      CAPM Beta                              1.328946
#                      Correlation                            0.823564
